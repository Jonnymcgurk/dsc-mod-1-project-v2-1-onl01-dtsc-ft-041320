# %%
from requests import get
url = 'http://www.imdb.com/search/title?release_date=2019&sort=num_votes,desc&page=1'
response = get(url)
print(response.text[:500])
# Out:
# <!DOCTYPE html>
# <html
#     xmlns:og="http://ogp.me/ns#"
#     xmlns:fb="http://www.facebook.com/2008/fbml">
#     <head>
#
#         <meta charset="utf-8">
#         <meta http-equiv="X-UA-Compatible" content="IE=edge">
#
#     <meta name="apple-itunes-app" content="app-id=342792525, app-argument=imdb:///?src=mdot">
#
#
#
#         <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:'java'};</script>
#
# <script>
#     if (typeof uet == 'function') {
#       uet("bb", "LoadTitle"

# %%
import pandas as pd
from bs4 import BeautifulSoup
html_soup = BeautifulSoup(response.text, 'html.parser')
type(html_soup)I I
# Out:
# bs4.BeautifulSoup

# %%
movie_containers = html_soup.find_all('div', class_ = 'lister-item mode-advanced')
print(type(movie_containers))
print(len(movie_containers))
# Out:
# <class 'bs4.element.ResultSet'>
# 50

# %%
dlist = []
for container in movie_containers:
    d ={}
    
    d['name'] = container.find('h3', class_="lister-item-header").text
    
    d['imdb_rating'] = container.find('div',class_ = "inline-block ratings-imdb-rating").text
    try:
        d["meta_score"] = container.find('div', class_= "inline-block ratings-metascore").text
    except:
        d['meta_score'] = None 
    dlist.append(d)

# %%
dic_list = pd.DataFrame(dlist)
dic_list
# Out:
#                                                  name imdb_rating  \
# 0                               \n1.\nJoker\n(2019)\n   \n\n8.5\n
# 1                   \n2.\nAvengers: Endgame\n(2019)\n   \n\n8.4\n
# 2    \n3.\nOnce Upon a Time... in Hollywood\n(2019)\n   \n\n7.7\n
# 3                           \n4.\nChernobyl\n(2019)\n   \n\n9.4\n
# 4                      \n5.\nCaptain Marvel\n(2019)\n   \n\n6.9\n
# 5                            \n6.\nParasite\n(2019)\n   \n\n8.6\n
# 6    \n7.\nStar Wars: The Rise of Skywalker\n(2019)\n   \n\n6.7\n
# 7                                \n8.\n1917\n(2019)\n   \n\n8.3\n
# 8                          \n9.\nKnives Out\n(2019)\n   \n\n7.9\n
# 9          \n10.\nSpider-Man: Far from Home\n(2019)\n   \n\n7.5\n
# 10                      \n11.\nThe Irishman\n(2019)\n   \n\n7.9\n
# 11                     \n12.\nThe Witcher\n(2019– )\n   \n\n8.3\n
# 12  \n13.\nJohn Wick: Chapter 3 - Parabellum\n(201...   \n\n7.5\n
# 13                           \n14.\nShazam!\n(2019)\n   \n\n7.1\n
# 14  \n15.\n Game of Thrones (2011–2019)\n\nEpisode...   \n\n4.1\n
# 15                       \n16.\nLe Mans '66\n(2019)\n   \n\n8.1\n
# 16                    \n17.\nMarriage Story\n(2019)\n   \n\n8.0\n
# 17                       \n18.\nJojo Rabbit\n(2019)\n   \n\n7.9\n
# 18               \n19.\nAlita: Battle Angel\n(2019)\n   \n\n7.3\n
# 19                           \n20.\nAladdin\n(2019)\n   \n\n7.0\n
# 20  \n21.\n Game of Thrones (2011–2019)\n\nEpisode...   \n\n7.5\n
# 21                           \n22.\nUs\n(II) (2019)\n   \n\n6.9\n
# 22                             \n23.\nGlass\n(2019)\n   \n\n6.7\n
# 23                     \n24.\nThe Lion King\n(2019)\n   \n\n6.9\n
# 24  \n25.\n Game of Thrones (2011–2019)\n\nEpisode...   \n\n6.0\n
# 25                       \n26.\nToy Story 4\n(2019)\n   \n\n7.8\n
# 26                    \n27.\nIt Chapter Two\n(2019)\n   \n\n6.6\n
# 27                 \n28.\nThe Mandalorian\n(2019– )\n   \n\n8.7\n
# 28                          \n29.\nAd Astra\n(2019)\n   \n\n6.6\n
# 29   \n30.\nEl Camino: A Breaking Bad Movie\n(2019)\n   \n\n7.4\n
# 30                        \n31.\nUncut Gems\n(2019)\n   \n\n7.5\n
# 31  \n32.\n Game of Thrones (2011–2019)\n\nEpisode...   \n\n5.5\n
# 32                         \n33.\nMidsommar\n(2019)\n   \n\n7.1\n
# 33      \n34.\nFast & Furious: Hobbs & Shaw\n(2019)\n   \n\n6.5\n
# 34                        \n35.\nThe Boys\n(2019– )\n   \n\n8.7\n
# 35           \n36.\nJumanji: The Next Level\n(2019)\n   \n\n6.7\n
# 36               \n37.\nX-Men: Dark Phoenix\n(2019)\n   \n\n5.8\n
# 37                   \n38.\nSex Education\n(2019– )\n   \n\n8.3\n
# 38                     \n39.\nThe Gentlemen\n(2019)\n   \n\n7.9\n
# 39         \n40.\nPokémon Detective Pikachu\n(2019)\n   \n\n6.6\n
# 40  \n41.\n Game of Thrones (2011–2019)\n\nEpisode...   \n\n7.6\n
# 41  \n42.\n Game of Thrones (2011–2019)\n\nEpisode...   \n\n7.9\n
# 42    \n43.\nGodzilla: King of the Monsters\n(2019)\n   \n\n6.1\n
# 43                     \n44.\n6 Underground\n(2019)\n   \n\n6.1\n
# 44             \n45.\nTerminator: Dark Fate\n(2019)\n   \n\n6.3\n
# 45                      \n46.\nThe Platform\n(2019)\n   \n\n7.0\n
# 46                     \n47.\nRocketman\n(I) (2019)\n   \n\n7.3\n
# 47            \n48.\nZombieland: Double Tap\n(2019)\n   \n\n6.8\n
# 48                         \n49.\nFrozen II\n(2019)\n   \n\n7.0\n
# 49                      \n50.\nDoctor Sleep\n(2019)\n   \n\n7.4\n
#
#                                        meta_score
# 0   \n59        \n        Metascore\n
# 1   \n78        \n        Metascore\n
# 2   \n83        \n        Metascore\n
# 3                                            None
# 4   \n64        \n        Metascore\n
# 5   \n96        \n        Metascore\n
# 6   \n53        \n        Metascore\n
# 7   \n78        \n        Metascore\n
# 8   \n82        \n        Metascore\n
# 9   \n69        \n        Metascore\n
# 10  \n94        \n        Metascore\n
# 11                                           None
# 12  \n73        \n        Metascore\n
# 13  \n71        \n        Metascore\n
# 14                                           None
# 15  \n81        \n        Metascore\n
# 16  \n94        \n        Metascore\n
# 17  \n58        \n        Metascore\n
# 18  \n53        \n        Metascore\n
# 19  \n53        \n        Metascore\n
# 20                                           None
# 21  \n81        \n        Metascore\n
# 22  \n43        \n        Metascore\n
# 23  \n55        \n        Metascore\n
# 24                                           None
# 25  \n84        \n        Metascore\n
# 26  \n58        \n        Metascore\n
# 27                                           None
# 28  \n80        \n        Metascore\n
# 29  \n72        \n        Metascore\n
# 30  \n90        \n        Metascore\n
# 31                                           None
# 32  \n72        \n        Metascore\n
# 33  \n60        \n        Metascore\n
# 34                                           None
# 35  \n58        \n        Metascore\n
# 36  \n43        \n        Metascore\n
# 37                                           None
# 38  \n51        \n        Metascore\n
# 39  \n53        \n        Metascore\n
# 40                                           None
# 41                                           None
# 42  \n48        \n        Metascore\n
# 43  \n41        \n        Metascore\n
# 44  \n54        \n        Metascore\n
# 45  \n73        \n        Metascore\n
# 46  \n69        \n        Metascore\n
# 47  \n55        \n        Metascore\n
# 48  \n64        \n        Metascore\n
# 49  \n59        \n        Metascore\n

# %%
dic_list = dic_list.replace(r'\n',  ' ', regex=True)
dic_list
# Out:
#                                                  name imdb_rating  \
# 0                                    1. Joker (2019)         8.5
# 1                        2. Avengers: Endgame (2019)         8.4
# 2         3. Once Upon a Time... in Hollywood (2019)         7.7
# 3                                4. Chernobyl (2019)         9.4
# 4                           5. Captain Marvel (2019)         6.9
# 5                                 6. Parasite (2019)         8.6
# 6         7. Star Wars: The Rise of Skywalker (2019)         6.7
# 7                                     8. 1917 (2019)         8.3
# 8                               9. Knives Out (2019)         7.9
# 9               10. Spider-Man: Far from Home (2019)         7.5
# 10                           11. The Irishman (2019)         7.9
# 11                          12. The Witcher (2019– )         8.3
# 12      13. John Wick: Chapter 3 - Parabellum (2019)         7.5
# 13                                14. Shazam! (2019)         7.1
# 14   15.  Game of Thrones (2011–2019)  Episode: Th...        4.1
# 15                            16. Le Mans '66 (2019)         8.1
# 16                         17. Marriage Story (2019)         8.0
# 17                            18. Jojo Rabbit (2019)         7.9
# 18                    19. Alita: Battle Angel (2019)         7.3
# 19                                20. Aladdin (2019)         7.0
# 20   21.  Game of Thrones (2011–2019)  Episode: Th...        7.5
# 21                                22. Us (II) (2019)         6.9
# 22                                  23. Glass (2019)         6.7
# 23                          24. The Lion King (2019)         6.9
# 24   25.  Game of Thrones (2011–2019)  Episode: Th...        6.0
# 25                            26. Toy Story 4 (2019)         7.8
# 26                         27. It Chapter Two (2019)         6.6
# 27                      28. The Mandalorian (2019– )         8.7
# 28                               29. Ad Astra (2019)         6.6
# 29        30. El Camino: A Breaking Bad Movie (2019)         7.4
# 30                             31. Uncut Gems (2019)         7.5
# 31   32.  Game of Thrones (2011–2019)  Episode: Th...        5.5
# 32                              33. Midsommar (2019)         7.1
# 33           34. Fast & Furious: Hobbs & Shaw (2019)         6.5
# 34                             35. The Boys (2019– )         8.7
# 35                36. Jumanji: The Next Level (2019)         6.7
# 36                    37. X-Men: Dark Phoenix (2019)         5.8
# 37                        38. Sex Education (2019– )         8.3
# 38                          39. The Gentlemen (2019)         7.9
# 39              40. Pokémon Detective Pikachu (2019)         6.6
# 40   41.  Game of Thrones (2011–2019)  Episode: Wi...        7.6
# 41   42.  Game of Thrones (2011–2019)  Episode: A ...        7.9
# 42         43. Godzilla: King of the Monsters (2019)         6.1
# 43                          44. 6 Underground (2019)         6.1
# 44                  45. Terminator: Dark Fate (2019)         6.3
# 45                           46. The Platform (2019)         7.0
# 46                          47. Rocketman (I) (2019)         7.3
# 47                 48. Zombieland: Double Tap (2019)         6.8
# 48                              49. Frozen II (2019)         7.0
# 49                           50. Doctor Sleep (2019)         7.4
#
#                                     meta_score
# 0    59                 Metascore
# 1    78                 Metascore
# 2    83                 Metascore
# 3                                         None
# 4    64                 Metascore
# 5    96                 Metascore
# 6    53                 Metascore
# 7    78                 Metascore
# 8    82                 Metascore
# 9    69                 Metascore
# 10   94                 Metascore
# 11                                        None
# 12   73                 Metascore
# 13   71                 Metascore
# 14                                        None
# 15   81                 Metascore
# 16   94                 Metascore
# 17   58                 Metascore
# 18   53                 Metascore
# 19   53                 Metascore
# 20                                        None
# 21   81                 Metascore
# 22   43                 Metascore
# 23   55                 Metascore
# 24                                        None
# 25   84                 Metascore
# 26   58                 Metascore
# 27                                        None
# 28   80                 Metascore
# 29   72                 Metascore
# 30   90                 Metascore
# 31                                        None
# 32   72                 Metascore
# 33   60                 Metascore
# 34                                        None
# 35   58                 Metascore
# 36   43                 Metascore
# 37                                        None
# 38   51                 Metascore
# 39   53                 Metascore
# 40                                        None
# 41                                        None
# 42   48                 Metascore
# 43   41                 Metascore
# 44   54                 Metascore
# 45   73                 Metascore
# 46   69                 Metascore
# 47   55                 Metascore
# 48   64                 Metascore
# 49   59                 Metascore

# %%
dic_list.dropna(axis=0, how="any", thresh=None, subset=None, inplace=False)
# Out:
#                                               name imdb_rating  \
# 0                                 1. Joker (2019)         8.5
# 1                     2. Avengers: Endgame (2019)         8.4
# 2      3. Once Upon a Time... in Hollywood (2019)         7.7
# 4                        5. Captain Marvel (2019)         6.9
# 5                              6. Parasite (2019)         8.6
# 6      7. Star Wars: The Rise of Skywalker (2019)         6.7
# 7                                  8. 1917 (2019)         8.3
# 8                            9. Knives Out (2019)         7.9
# 9            10. Spider-Man: Far from Home (2019)         7.5
# 10                        11. The Irishman (2019)         7.9
# 12   13. John Wick: Chapter 3 - Parabellum (2019)         7.5
# 13                             14. Shazam! (2019)         7.1
# 15                         16. Le Mans '66 (2019)         8.1
# 16                      17. Marriage Story (2019)         8.0
# 17                         18. Jojo Rabbit (2019)         7.9
# 18                 19. Alita: Battle Angel (2019)         7.3
# 19                             20. Aladdin (2019)         7.0
# 21                             22. Us (II) (2019)         6.9
# 22                               23. Glass (2019)         6.7
# 23                       24. The Lion King (2019)         6.9
# 25                         26. Toy Story 4 (2019)         7.8
# 26                      27. It Chapter Two (2019)         6.6
# 28                            29. Ad Astra (2019)         6.6
# 29     30. El Camino: A Breaking Bad Movie (2019)         7.4
# 30                          31. Uncut Gems (2019)         7.5
# 32                           33. Midsommar (2019)         7.1
# 33        34. Fast & Furious: Hobbs & Shaw (2019)         6.5
# 35             36. Jumanji: The Next Level (2019)         6.7
# 36                 37. X-Men: Dark Phoenix (2019)         5.8
# 38                       39. The Gentlemen (2019)         7.9
# 39           40. Pokémon Detective Pikachu (2019)         6.6
# 42      43. Godzilla: King of the Monsters (2019)         6.1
# 43                       44. 6 Underground (2019)         6.1
# 44               45. Terminator: Dark Fate (2019)         6.3
# 45                        46. The Platform (2019)         7.0
# 46                       47. Rocketman (I) (2019)         7.3
# 47              48. Zombieland: Double Tap (2019)         6.8
# 48                           49. Frozen II (2019)         7.0
# 49                        50. Doctor Sleep (2019)         7.4
#
#                                     meta_score
# 0    59                 Metascore
# 1    78                 Metascore
# 2    83                 Metascore
# 4    64                 Metascore
# 5    96                 Metascore
# 6    53                 Metascore
# 7    78                 Metascore
# 8    82                 Metascore
# 9    69                 Metascore
# 10   94                 Metascore
# 12   73                 Metascore
# 13   71                 Metascore
# 15   81                 Metascore
# 16   94                 Metascore
# 17   58                 Metascore
# 18   53                 Metascore
# 19   53                 Metascore
# 21   81                 Metascore
# 22   43                 Metascore
# 23   55                 Metascore
# 25   84                 Metascore
# 26   58                 Metascore
# 28   80                 Metascore
# 29   72                 Metascore
# 30   90                 Metascore
# 32   72                 Metascore
# 33   60                 Metascore
# 35   58                 Metascore
# 36   43                 Metascore
# 38   51                 Metascore
# 39   53                 Metascore
# 42   48                 Metascore
# 43   41                 Metascore
# 44   54                 Metascore
# 45   73                 Metascore
# 46   69                 Metascore
# 47   55                 Metascore
# 48   64                 Metascore
# 49   59                 Metascore

# %%
movie_ratings = pd.DataFrame(dic_list)
({'movie': name,
'imdb': imdb_rating,
'metascore': meta_score
})
print(movie_ratings.info())
movie_ratings.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 3 columns):
# name           50 non-null object
# imdb_rating    50 non-null object
# meta_score     39 non-null object
# dtypes: object(3)
# memory usage: 1.3+ KB
# None
#                                                name imdb_rating  \
# 0                             \n1.\nJoker\n(2019)\n   \n\n8.5\n
# 1                 \n2.\nAvengers: Endgame\n(2019)\n   \n\n8.4\n
# 2  \n3.\nOnce Upon a Time... in Hollywood\n(2019)\n   \n\n7.7\n
# 3                         \n4.\nChernobyl\n(2019)\n   \n\n9.4\n
# 4                    \n5.\nCaptain Marvel\n(2019)\n   \n\n6.9\n
# 5                          \n6.\nParasite\n(2019)\n   \n\n8.6\n
# 6  \n7.\nStar Wars: The Rise of Skywalker\n(2019)\n   \n\n6.7\n
# 7                              \n8.\n1917\n(2019)\n   \n\n8.3\n
# 8                        \n9.\nKnives Out\n(2019)\n   \n\n7.9\n
# 9        \n10.\nSpider-Man: Far from Home\n(2019)\n   \n\n7.5\n
#
#                                       meta_score
# 0  \n59        \n        Metascore\n
# 1  \n78        \n        Metascore\n
# 2  \n83        \n        Metascore\n
# 3                                           None
# 4  \n64        \n        Metascore\n
# 5  \n96        \n        Metascore\n
# 6  \n53        \n        Metascore\n
# 7  \n78        \n        Metascore\n
# 8  \n82        \n        Metascore\n
# 9  \n69        \n        Metascore\n

# %%
movie_ratings = movie_ratings.dropna(axis=0, how="any", thresh=None, subset=None, inplace=False)

# %%
movie_ratings = movie_ratings.replace(r'\n',  ' ', regex=True)
movie_ratings
# Out:
#                                               name  imdb_rating  \
# 0                                 1. Joker (2019)           8.5
# 1                     2. Avengers: Endgame (2019)           8.4
# 2      3. Once Upon a Time... in Hollywood (2019)           7.7
# 4                        5. Captain Marvel (2019)           6.9
# 5                              6. Parasite (2019)           8.6
# 6      7. Star Wars: The Rise of Skywalker (2019)           6.7
# 7                                  8. 1917 (2019)           8.3
# 8                            9. Knives Out (2019)           7.9
# 9            10. Spider-Man: Far from Home (2019)           7.5
# 10                        11. The Irishman (2019)           7.9
# 12   13. John Wick: Chapter 3 - Parabellum (2019)           7.5
# 13                             14. Shazam! (2019)           7.1
# 15                         16. Le Mans '66 (2019)           8.1
# 16                      17. Marriage Story (2019)           8.0
# 17                         18. Jojo Rabbit (2019)           7.9
# 18                 19. Alita: Battle Angel (2019)           7.3
# 19                             20. Aladdin (2019)           7.0
# 21                             22. Us (II) (2019)           6.9
# 22                               23. Glass (2019)           6.7
# 23                       24. The Lion King (2019)           6.9
# 25                         26. Toy Story 4 (2019)           7.8
# 26                      27. It Chapter Two (2019)           6.6
# 28                            29. Ad Astra (2019)           6.6
# 29     30. El Camino: A Breaking Bad Movie (2019)           7.4
# 30                          31. Uncut Gems (2019)           7.5
# 32                           33. Midsommar (2019)           7.1
# 33        34. Fast & Furious: Hobbs & Shaw (2019)           6.5
# 35             36. Jumanji: The Next Level (2019)           6.7
# 36                 37. X-Men: Dark Phoenix (2019)           5.8
# 38                       39. The Gentlemen (2019)           7.9
# 39           40. Pokémon Detective Pikachu (2019)           6.6
# 42      43. Godzilla: King of the Monsters (2019)           6.1
# 43                       44. 6 Underground (2019)           6.1
# 44               45. Terminator: Dark Fate (2019)           6.3
# 45                        46. The Platform (2019)           7.0
# 46                       47. Rocketman (I) (2019)           7.3
# 47              48. Zombieland: Double Tap (2019)           6.8
# 48                           49. Frozen II (2019)           7.0
# 49                        50. Doctor Sleep (2019)           7.4
#
#                                     meta_score  n_imdb
# 0    59                 Metascore                 85.0
# 1    78                 Metascore                 84.0
# 2    83                 Metascore                 77.0
# 4    64                 Metascore                 69.0
# 5    96                 Metascore                 86.0
# 6    53                 Metascore                 67.0
# 7    78                 Metascore                 83.0
# 8    82                 Metascore                 79.0
# 9    69                 Metascore                 75.0
# 10   94                 Metascore                 79.0
# 12   73                 Metascore                 75.0
# 13   71                 Metascore                 71.0
# 15   81                 Metascore                 81.0
# 16   94                 Metascore                 80.0
# 17   58                 Metascore                 79.0
# 18   53                 Metascore                 73.0
# 19   53                 Metascore                 70.0
# 21   81                 Metascore                 69.0
# 22   43                 Metascore                 67.0
# 23   55                 Metascore                 69.0
# 25   84                 Metascore                 78.0
# 26   58                 Metascore                 66.0
# 28   80                 Metascore                 66.0
# 29   72                 Metascore                 74.0
# 30   90                 Metascore                 75.0
# 32   72                 Metascore                 71.0
# 33   60                 Metascore                 65.0
# 35   58                 Metascore                 67.0
# 36   43                 Metascore                 58.0
# 38   51                 Metascore                 79.0
# 39   53                 Metascore                 66.0
# 42   48                 Metascore                 61.0
# 43   41                 Metascore                 61.0
# 44   54                 Metascore                 63.0
# 45   73                 Metascore                 70.0
# 46   69                 Metascore                 73.0
# 47   55                 Metascore                 68.0
# 48   64                 Metascore                 70.0
# 49   59                 Metascore                 74.0

# %%
# new data frame with split value columns 
new = movie_ratings["meta_Score"].str.split(" ", n = 1, expand = True) 
  
# making separate first name column from new data frame 
data["meta_Score1"]= new[4] 
  
# making separate last name column from new data frame 
data["Last Name2"]= new[5] 
  
# Dropping old Name columns 
data.drop(columns =["meta_Score"], inplace = True) 
  
# df display 
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-4a8840556696> in <module>
#       1 # new data frame with split value columns
# ----> 2 new = movie_ratings["meta_Score"].str.split(" ", n = 1, expand = True)
#       3
#       4 # making separate first name column from new data frame
#       5 data["meta_Score1"]= new[4]
#
# NameError: name 'movie_ratings' is not defined

# %%
movie_ratings['imdb_rating'] = movie_ratings['imdb_rating'].astype(float)
movie_ratings['meta_score'] = movie_ratings['meta_score'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-159-cc771c094582> in <module>
#       1 movie_ratings['imdb_rating'] = movie_ratings['imdb_rating'].astype(float)
# ----> 2 movie_ratings['meta_score'] = movie_ratings['meta_score'].astype(float)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5880             # else, only a single dtype is given
#    5881             new_data = self._data.astype(
# -> 5882                 dtype=dtype, copy=copy, errors=errors, **kwargs
#    5883             )
#    5884             return self._constructor(new_data).__finalize__(self)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/internals/managers.py in astype(self, dtype, **kwargs)
#     579
#     580     def astype(self, dtype, **kwargs):
# --> 581         return self.apply("astype", dtype=dtype, **kwargs)
#     582
#     583     def convert(self, **kwargs):
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/internals/managers.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#     436                     kwargs[k] = obj.reindex(b_items, axis=axis, copy=align_copy)
#     437
# --> 438             applied = getattr(b, f)(**kwargs)
#     439             result_blocks = _extend_blocks(applied, result_blocks)
#     440
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors, values, **kwargs)
#     557
#     558     def astype(self, dtype, copy=False, errors="raise", values=None, **kwargs):
# --> 559         return self._astype(dtype, copy=copy, errors=errors, values=values, **kwargs)
#     560
#     561     def _astype(self, dtype, copy=False, errors="raise", values=None, **kwargs):
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/internals/blocks.py in _astype(self, dtype, copy, errors, values, **kwargs)
#     641                     # _astype_nansafe works fine with 1-d only
#     642                     vals1d = values.ravel()
# --> 643                     values = astype_nansafe(vals1d, dtype, copy=True, **kwargs)
#     644
#     645                 # TODO(extension)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     727     if copy or is_object_dtype(arr) or is_object_dtype(dtype):
#     728         # Explicit copy, or required since NumPy can't view from / to object.
# --> 729         return arr.astype(dtype, copy=True)
#     730
#     731     return arr.view(dtype)
#
# ValueError: could not convert string to float: ' 59                 Metascore             '

# %%
print(type('imdb_rating'))
# Out:
# <class 'str'>

# %%
movie_ratings['n_imdb'] = movie_ratings['imdb_rating'] * 10
movie_ratings.head(3)
# Out:
#                                            name  imdb_rating  \
# 0                              1. Joker (2019)           8.5
# 1                  2. Avengers: Endgame (2019)           8.4
# 2   3. Once Upon a Time... in Hollywood (2019)           7.7
#
#                                    meta_score  n_imdb
# 0   59                 Metascore                 85.0
# 1   78                 Metascore                 84.0
# 2   83                 Metascore                 77.0

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(nrows = 1, ncols = 3, figsize = (20,4))
ax1, ax2, ax3 = fig.axes
ax1.hist(movie_ratings['n_imdb'], bins = 10, range = (0,100))
ax1.set_title('IMDB rating')

ax2.hist(movie_ratings['meta_score'], bins = 10, range = (0,100)) # bin range = 10
ax2.set_title('Metascore')

ax3.hist(movie_ratings['n_imdb'], bins = 10, range = (0,100), histtype = 'step')
ax3.hist(movie_ratings['meta_score'], bins = 10, range = (0,100), histtype = 'step')

ax3.set_title('The Two Normalized Distributions')

for ax in fig.axes:
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
plt.show()
